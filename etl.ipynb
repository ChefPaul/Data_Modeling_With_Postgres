# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
import numpy as np
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data')
print(song_files)
# Out:
# ['/home/workspace/data/song_data/A/B/C/TRABCIX128F4265903.json', '/home/workspace/data/song_data/A/B/C/TRABCEI128F424C983.json', '/home/workspace/data/song_data/A/B/C/TRABCKL128F423A778.json', '/home/workspace/data/song_data/A/B/C/TRABCTK128F934B224.json', '/home/workspace/data/song_data/A/B/C/TRABCEC128F426456E.json', '/home/workspace/data/song_data/A/B/C/TRABCPZ128F4275C32.json', '/home/workspace/data/song_data/A/B/C/TRABCRU128F423F449.json', '/home/workspace/data/song_data/A/B/C/TRABCYE128F934CE1D.json', '/home/workspace/data/song_data/A/B/C/TRABCUQ128E0783E2B.json', '/home/workspace/data/song_data/A/B/C/TRABCAJ12903CDFCC2.json', '/home/workspace/data/song_data/A/B/C/TRABCFL128F149BB0D.json', '/home/workspace/data/song_data/A/B/C/TRABCXB128F4286BD3.json', '/home/workspace/data/song_data/A/B/B/TRABBNP128F932546F.json', '/home/workspace/data/song_data/A/B/B/TRABBOR128F4286200.json', '/home/workspace/data/song_data/A/B/B/TRABBBV128F42967D7.json', '/home/workspace/data/song_data/A/B/B/TRABBAM128F429D223.json', '/home/workspace/data/song_data/A/B/B/TRABBJE12903CDB442.json', '/home/workspace/data/song_data/A/B/B/TRABBZN12903CD9297.json', '/home/workspace/data/song_data/A/B/B/TRABBTA128F933D304.json', '/home/workspace/data/song_data/A/B/B/TRABBKX128F4285205.json', '/home/workspace/data/song_data/A/B/B/TRABBVJ128F92F7EAA.json', '/home/workspace/data/song_data/A/B/B/TRABBOP128F931B50D.json', '/home/workspace/data/song_data/A/B/B/TRABBXU128F92FEF48.json', '/home/workspace/data/song_data/A/B/B/TRABBLU128F93349CF.json', '/home/workspace/data/song_data/A/B/A/TRABACN128F425B784.json', '/home/workspace/data/song_data/A/B/A/TRABAIO128F42938F9.json', '/home/workspace/data/song_data/A/B/A/TRABAZH128F930419A.json', '/home/workspace/data/song_data/A/B/A/TRABAXV128F92F6AE3.json', '/home/workspace/data/song_data/A/B/A/TRABAWW128F4250A31.json', '/home/workspace/data/song_data/A/B/A/TRABAFJ128F42AF24E.json', '/home/workspace/data/song_data/A/B/A/TRABATO128F42627E9.json', '/home/workspace/data/song_data/A/B/A/TRABAVQ12903CBF7E0.json', '/home/workspace/data/song_data/A/B/A/TRABAXR128F426515F.json', '/home/workspace/data/song_data/A/B/A/TRABAXL128F424FC50.json', '/home/workspace/data/song_data/A/B/A/TRABAFP128F931E9A1.json', '/home/workspace/data/song_data/A/A/C/TRAACTB12903CAAF15.json', '/home/workspace/data/song_data/A/A/C/TRAACFV128F935E50B.json', '/home/workspace/data/song_data/A/A/C/TRAACHN128F1489601.json', '/home/workspace/data/song_data/A/A/C/TRAACPE128F421C1B9.json', '/home/workspace/data/song_data/A/A/C/TRAACER128F4290F96.json', '/home/workspace/data/song_data/A/A/C/TRAACLV128F427E123.json', '/home/workspace/data/song_data/A/A/C/TRAACZK128F4243829.json', '/home/workspace/data/song_data/A/A/C/TRAACNS128F14A2DF5.json', '/home/workspace/data/song_data/A/A/C/TRAACOW128F933E35F.json', '/home/workspace/data/song_data/A/A/C/TRAACQT128F9331780.json', '/home/workspace/data/song_data/A/A/C/TRAACIW12903CC0F6D.json', '/home/workspace/data/song_data/A/A/C/TRAACVS128E078BE39.json', '/home/workspace/data/song_data/A/A/C/TRAACSL128F93462F4.json', '/home/workspace/data/song_data/A/A/C/TRAACCG128F92E8A55.json', '/home/workspace/data/song_data/A/A/B/TRAABLR128F423B7E3.json', '/home/workspace/data/song_data/A/A/B/TRAABYW128F4244559.json', '/home/workspace/data/song_data/A/A/B/TRAABCL128F4286650.json', '/home/workspace/data/song_data/A/A/B/TRAABXG128F9318EBD.json', '/home/workspace/data/song_data/A/A/B/TRAABVM128F92CA9DC.json', '/home/workspace/data/song_data/A/A/B/TRAABJV128F1460C49.json', '/home/workspace/data/song_data/A/A/B/TRAABDL12903CAABBA.json', '/home/workspace/data/song_data/A/A/B/TRAABRB128F9306DD5.json', '/home/workspace/data/song_data/A/A/B/TRAABJL12903CDCF1A.json', '/home/workspace/data/song_data/A/A/B/TRAABYN12903CFD305.json', '/home/workspace/data/song_data/A/A/B/TRAABNV128F425CEE1.json', '/home/workspace/data/song_data/A/A/B/.ipynb_checkpoints/TRAABDL12903CAABBA-checkpoint.json', '/home/workspace/data/song_data/A/A/A/TRAAAMO128F1481E7F.json', ' ...

# %%
song_filepath = song_files[0]

# %%
song_df = pd.read_json(song_filepath, lines=True)
song_df.head()
# Out:
#             artist_id  artist_latitude           artist_location  \
# 0  ARNF6401187FB57032         40.79086  New York, NY [Manhattan]
#
#    artist_longitude        artist_name  duration  num_songs  \
# 0         -73.96644  Sophie B. Hawkins   305.162          1
#
#               song_id                          title  year
# 0  SONWXQJ12A8C134D94  The Ballad Of Sleeping Beauty  1994

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
import numpy
songs_col = ['song_id', 'title', 'artist_id', 'year', 'duration']
#song_data = (df['song_id'].values, df['title'].values, df['artist_id'].values, df['year'].values, df['duration'].values)
song_data = song_df[songs_col].values.tolist()[0]
song_data
#song_data.tolist()[0]
#song_data = np.array(song_data)
#song_data = list(song_data)
#song_data
# Out:
# ['SONWXQJ12A8C134D94',
#  'The Ballad Of Sleeping Beauty',
#  'ARNF6401187FB57032',
#  1994,
#  305.162]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artists_col = ['artist_id', 'title', 'artist_location', 'artist_latitude', 'artist_longitude']
artist_data = song_df[artists_col].values.tolist()[0]
artist_data
# Out:
# ['ARNF6401187FB57032',
#  'The Ballad Of Sleeping Beauty',
#  'New York, NY [Manhattan]',
#  40.79086,
#  -73.96644]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
log_filepath = log_files[0]
log_filepath
# Out:
# '/home/workspace/data/log_data/2018/11/2018-11-09-events.json'

# %%
log_df = pd.read_json(log_filepath, lines=True)
log_df.head()
# Out:
#                  artist       auth firstName gender  itemInSession lastName  \
# 0                  Muse  Logged In    Harper      M              1  Barrett
# 1          Beastie Boys  Logged In    Harper      M              2  Barrett
# 2               Shakira  Logged In    Harper      M              3  Barrett
# 3                Selena  Logged In    Harper      M              4  Barrett
# 4  Kid Cudi Vs Crookers  Logged In    Harper      M              5  Barrett
#
#       length level                               location method      page  \
# 0  209.50159  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 1  161.56689  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 2  145.84118  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 3  172.66893  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 4  162.97751  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
#
#    registration  sessionId                                               song  \
# 0  1.540685e+12        275  Supermassive Black Hole (Twilight Soundtrack V...
# 1  1.540685e+12        275                                         Lighten Up
# 2  1.540685e+12        275                                       Pienso En Ti
# 3  1.540685e+12        275                                     Amor Prohibido
# 4  1.540685e+12        275                                       Day 'N' Nite
#
#    status             ts                                          userAgent  \
# 0     200  1541721977796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 1     200  1541722186796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 2     200  1541722347796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 3     200  1541722492796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 4     200  1541722664796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
#
#   userId
# 0     42
# 1     42
# 2     42
# 3     42
# 4     42

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
#log_df = pd.read_json(log_filepath, lines=True)
log_df = log_df.loc[log_df['page'] == 'NextSong']
log_df.head()
# Out:
#                  artist       auth firstName gender  itemInSession lastName  \
# 0                  Muse  Logged In    Harper      M              1  Barrett
# 1          Beastie Boys  Logged In    Harper      M              2  Barrett
# 2               Shakira  Logged In    Harper      M              3  Barrett
# 3                Selena  Logged In    Harper      M              4  Barrett
# 4  Kid Cudi Vs Crookers  Logged In    Harper      M              5  Barrett
#
#       length level                               location method      page  \
# 0  209.50159  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 1  161.56689  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 2  145.84118  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 3  172.66893  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 4  162.97751  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
#
#    registration  sessionId                                               song  \
# 0  1.540685e+12        275  Supermassive Black Hole (Twilight Soundtrack V...
# 1  1.540685e+12        275                                         Lighten Up
# 2  1.540685e+12        275                                       Pienso En Ti
# 3  1.540685e+12        275                                     Amor Prohibido
# 4  1.540685e+12        275                                       Day 'N' Nite
#
#    status             ts                                          userAgent  \
# 0     200  1541721977796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 1     200  1541722186796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 2     200  1541722347796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 3     200  1541722492796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 4     200  1541722664796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
#
#   userId
# 0     42
# 1     42
# 2     42
# 3     42
# 4     42

# %%
t = pd.to_datetime(log_df['ts'])
t.head()
# Out:
# 0   1970-01-01 00:25:41.721977796
# 1   1970-01-01 00:25:41.722186796
# 2   1970-01-01 00:25:41.722347796
# 3   1970-01-01 00:25:41.722492796
# 4   1970-01-01 00:25:41.722664796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (t, t.dt.hour, t.dt.day, t.dt.week, t.dt.month, t.dt.year, t.dt.weekday)
column_labels = ('start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday')

# %%
time_df = pd.DataFrame({'start_time': time_data[0],
                        'hour': time_data[1],
                        'day': time_data[2],
                        'week': time_data[3],
                        'month': time_data[4],
                        'year': time_data[5],
                        'weekday': time_data[6]})
time_df.head()
# Out:
#                      start_time  hour  day  week  month  year  weekday
# 0 1970-01-01 00:25:41.721977796     0    1     1      1  1970        3
# 1 1970-01-01 00:25:41.722186796     0    1     1      1  1970        3
# 2 1970-01-01 00:25:41.722347796     0    1     1      1  1970        3
# 3 1970-01-01 00:25:41.722492796     0    1     1      1  1970        3
# 4 1970-01-01 00:25:41.722664796     0    1     1      1  1970        3

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_col = ['userId', 'firstName', 'lastName', 'gender', 'level']
user_df = log_df[user_col]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in log_df.iterrows():
    #if (title = row.song AND name = row.artist AND duration = row.length):
    print(index, row)    
    
    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    print(song_select)
    
    results = cur.fetchone()
    #print(results)
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
    
    print(results)
    
    # insert songplay record
    songplay_data = [index, pd.to_datetime(row.ts, unit='ms'), row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent]
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# 0 artist                                                        Muse
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    1
# lastName                                                   Barrett
# length                                                     209.502
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song             Supermassive Black Hole (Twilight Soundtrack V...
# status                                                         200
# ts                                                   1541721977796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 0, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 1 artist                                                Beastie Boys
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    2
# lastName                                                   Barrett
# length                                                     161.567
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                    Lighten Up
# status                                                         200
# ts                                                   1541722186796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 1, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 2 artist                                                     Shakira
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    3
# lastName                                                   Barrett
# length                                                     145.841
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                  Pienso En Ti
# status                                                         200
# ts                                                   1541722347796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 2, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 3 artist                                                      Selena
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    4
# lastName                                                   Barrett
# length                                                     172.669
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                Amor Prohibido
# status                                                         200
# ts                                                   1541722492796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 3, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 4 artist                                        Kid Cudi Vs Crookers
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    5
# lastName                                                   Barrett
# length                                                     162.978
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                  Day 'N' Nite
# status                                                         200
# ts                                                   1541722664796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 4, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 5 artist                                                Rise Against
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    6
# lastName                                                   Barrett
# length                                                     179.591
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                        Black Masks & Gasoline
# status                                                         200
# ts                                                   1541722826796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 5, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 6 artist                                                Fall Out Boy
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    7
# lastName                                                   Barrett
# length                                                     211.696
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song             I'm Like A Lawyer With The Way I'm Always Tryi...
# status                                                         200
# ts                                                   1541723005796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 6, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 7 artist                                                Jack Johnson
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    8
# lastName                                                   Barrett
# length                                                     196.127
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                            Staple It Together
# status                                                         200
# ts                                                   1541723216796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 7, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 8 artist                        Twista feat. Kayne West & Jamie Foxx
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                    9
# lastName                                                   Barrett
# length                                                     212.558
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song             Slow Jamz (Feat. Kanye West & Jamie Foxx) (Edi...
# status                                                         200
# ts                                                   1541723412796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 8, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 9 artist                                                       Train
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   10
# lastName                                                   Barrett
# length                                                     216.764
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                              Hey_ Soul Sister
# status                                                         200
# ts                                                   1541723624796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 9, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 10 artist                                                     Rihanna
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   11
# lastName                                                   Barrett
# length                                                     293.825
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                         Rehab
# status                                                         200
# ts                                                   1541723840796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 10, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 11 artist                                                     Man Man
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   12
# lastName                                                   Barrett
# length                                                     222.458
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                           Van Helsing Boombox
# status                                                         200
# ts                                                   1541724133796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 11, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 12 artist                                                        Ween
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   13
# lastName                                                   Barrett
# length                                                      276.14
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                  The Stallion
# status                                                         200
# ts                                                   1541724355796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 12, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 13 artist                                          Charttraxx Karaoke
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   14
# lastName                                                   Barrett
# length                                                     225.175
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                     Fireflies
# status                                                         200
# ts                                                   1541724631796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 13, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 14 artist                                                  Digitalism
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   15
# lastName                                                   Barrett
# length                                                     208.248
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                 I Want I Want
# status                                                         200
# ts                                                   1541724856796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 14, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 15 artist                                                    Dispatch
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   16
# lastName                                                   Barrett
# length                                                      247.51
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                       Railway
# status                                                         200
# ts                                                   1541725064796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 15, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 16 artist                                              Postal Service
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   17
# lastName                                                   Barrett
# length                                                     294.478
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                           Clark Gable (Album)
# status                                                         200
# ts                                                   1541725311796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 16, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 17 artist                                             Patricia Barber
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   18
# lastName                                                   Barrett
# length                                                     317.831
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                       Phaeton
# status                                                         200
# ts                                                   1541725605796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 17, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 18 artist                                                        Enur
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   19
# lastName                                                   Barrett
# length                                                     203.467
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song             Ucci Ucci feat. Nicki Minaj & The Chopper City...
# status                                                         200
# ts                                                   1541725922796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 18, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 19 artist                                                      Hybrid
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   20
# lastName                                                   Barrett
# length                                                     379.611
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                         Choke
# status                                                         200
# ts                                                   1541726125796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 19, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 20 artist                                                   Riverside
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   21
# lastName                                                   Barrett
# length                                                     236.277
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                 Stuck Between
# status                                                         200
# ts                                                   1541726504796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 20, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 21 artist                                                      Enigma
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   22
# lastName                                                   Barrett
# length                                                     272.483
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                              Smell Of Desire.
# status                                                         200
# ts                                                   1541726740796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 21, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 22 artist                                                 Arcade Fire
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   23
# lastName                                                   Barrett
# length                                                     267.807
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                 Headlights Look Like Diamonds
# status                                                         200
# ts                                                   1541727012796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 22, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 24 artist                                                       Spoon
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   25
# lastName                                                   Barrett
# length                                                     274.364
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                             Out Go The Lights
# status                                                         200
# ts                                                   1541727279796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 24, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 25 artist                                               The Wannadies
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   26
# lastName                                                   Barrett
# length                                                     170.866
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                 You & Me Song
# status                                                         200
# ts                                                   1541727553796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 25, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 26 artist                                                      Tricky
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   27
# lastName                                                   Barrett
# length                                                     261.433
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                         Girls (Album version)
# status                                                         200
# ts                                                   1541727723796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 26, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 27 artist                                                   Tony Rice
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   28
# lastName                                                   Barrett
# length                                                     321.985
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                            Wayfaring Stranger
# status                                                         200
# ts                                                   1541727984796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 27, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 28 artist                                                    Rasheeda
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   29
# lastName                                                   Barrett
# length                                                     212.401
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                             Sweep The Flo (Featuring Diamond)
# status                                                         200
# ts                                                   1541728305796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 28, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 29 artist                                               George Younce
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   30
# lastName                                                   Barrett
# length                                                     191.686
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                      This Old House w/ When The Saints Medley
# status                                                         200
# ts                                                   1541728517796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 29, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 30 artist                                                 Alex Gopher
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   31
# lastName                                                   Barrett
# length                                                     221.622
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                   Brain Leech
# status                                                         200
# ts                                                   1541728708796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 30, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 31 artist                                                  Aphex Twin
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   32
# lastName                                                   Barrett
# length                                                     430.184
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                                    Didgeridoo
# status                                                         200
# ts                                                   1541728929796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 31, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 32 artist                                              Emmanuel Moire
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   33
# lastName                                                   Barrett
# length                                                      277.08
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                           LÃÂ  OÃÂ¹ Je Pars
# status                                                         200
# ts                                                   1541729359796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 32, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 33 artist                                                 Josh Turner
# auth                                                     Logged In
# firstName                                                   Harper
# gender                                                           M
# itemInSession                                                   34
# lastName                                                   Barrett
# length                                                     212.166
# level                                                         paid
# location                     New York-Newark-Jersey City, NY-NJ-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54069e+12
# sessionId                                                      275
# song                                           I Wouldn't Be A Man
# status                                                         200
# ts                                                   1541729636796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          42
# Name: 33, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 34 artist                                            Carlos Y JosÃÂ©
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    0
# lastName                                                    Cuevas
# length                                                     166.452
# level                                                         free
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54094e+12
# sessionId                                                      336
# song                                                Soy AlbaÃÂ±il
# status                                                         200
# ...
# userId                                                          25
# Name: 271, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 272 artist                                                    OceanLab
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                    5
# lastName                                                    Graves
# length                                                     440.842
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                              Clear Blue Water
# status                                                         200
# ts                                                   1541803601796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 272, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 273 artist                                               Dwight Yoakam
# auth                                                     Logged In
# firstName                                                 Mohammad
# gender                                                           M
# itemInSession                                                    0
# lastName                                                 Rodriguez
# length                                                     239.307
# level                                                         free
# location                   Sacramento--Roseville--Arden-Arcade, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54051e+12
# sessionId                                                      325
# song                                                You're The One
# status                                                         200
# ts                                                   1541803618796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          88
# Name: 273, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 274 artist                                       The Devil Wears Prada
# auth                                                     Logged In
# firstName                                                 Mohammad
# gender                                                           M
# itemInSession                                                    1
# lastName                                                 Rodriguez
# length                                                     205.662
# level                                                         free
# location                   Sacramento--Roseville--Arden-Arcade, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54051e+12
# sessionId                                                      325
# song                                                     Lord Xenu
# status                                                         200
# ts                                                   1541803857796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          88
# Name: 274, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 275 artist                                                 Eva Cassidy
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                    6
# lastName                                                    Graves
# length                                                     248.868
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                          Take Me To The River
# status                                                         200
# ts                                                   1541804041796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 275, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 276 artist                                                    Mr. Oizo
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                    7
# lastName                                                    Graves
# length                                                     325.224
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                                     Flat Beat
# status                                                         200
# ts                                                   1541804289796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 276, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 277 artist                                                Mariah Carey
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                    8
# lastName                                                    Graves
# length                                                     261.642
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                                 Never Too Far
# status                                                         200
# ts                                                   1541804614796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 277, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 278 artist                                        Kid Cudi Vs Crookers
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                    9
# lastName                                                    Graves
# length                                                     162.978
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                                  Day 'N' Nite
# status                                                         200
# ts                                                   1541804875796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 278, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 279 artist                                                 Pat Martino
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                   10
# lastName                                                    Graves
# length                                                     355.944
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                                     El Hombre
# status                                                         200
# ts                                                   1541805037796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 279, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 280 artist                                                  Jason Mraz
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                   11
# lastName                                                    Graves
# length                                                     218.409
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                             Geek In The Pink [Phil Tan Remix]
# status                                                         200
# ts                                                   1541805392796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 280, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 281 artist                                               Dwight Yoakam
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                   12
# lastName                                                    Graves
# length                                                     239.307
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                                You're The One
# status                                                         200
# ts                                                   1541805610796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 281, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None
# 282 artist                              Smokey Robinson & The Miracles
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                   13
# lastName                                                    Graves
# length                                                     168.907
# level                                                         paid
# location                                          Marinette, WI-MI
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54066e+12
# sessionId                                                      297
# song                                         I Second That Emotion
# status                                                         200
# ts                                                   1541805849796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          25
# Name: 282, dtype: object
# SELECT songs.song_id, artists.artist_id FROM (songs LEFT JOIN artists ON artists.artist_id = songs.artist_id) WHERE songs.title = (%s) AND artists.name = (%s) AND songs.duration = (%s)
# None

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
